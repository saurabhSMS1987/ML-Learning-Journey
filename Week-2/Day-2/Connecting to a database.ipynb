# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /opt/anaconda3/lib/python3.12/site-packages (9.7.0)

# %%
import pandas as pd
import mysql.connector

# %%
connect = mysql.connector.connect(
host= 'localhost',
user= 'root',
password='PandasTutorial',
database='parks_and_recreation'
)

# %%
query = 'SELECT * FROM parks_and_recreation.employee_demographics'

# %%
pd.read_sql(query, connect)

# %%
connect.close()
